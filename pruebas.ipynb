# %%
import pandas as pd
import streamlit as st
from gdeltdoc import GdeltDoc, repeat, Filters, near
from datetime import datetime, timedelta

# %%
gd = GdeltDoc()

# %%
inicio_dias = datetime(2017, 1, 1)
yesterday = datetime.now() - timedelta(2)
fecha_inicio_imp, first_date, fecha_inicio = datetime.strftime(inicio_dias, "%d-%B-%Y"), datetime.strftime(inicio_dias, "%Y %b %d"), datetime.strftime(inicio_dias, "%Y-%m-%d")
fecha_fin_imp, last_date, fecha_fin = datetime.strftime(yesterday, "%d-%B-%Y"), datetime.strftime(yesterday, "%Y %b %d"), datetime.strftime(yesterday, "%Y-%m-%d")

# %%
fecha_inicio = "2017-01-01"

# %%
etnia = "Maasai"

# %%
fecha_inicio
# Out:
# '2017-01-01'

# %%
f = Filters(
start_date = fecha_inicio,
end_date = fecha_fin,
#keyword = ["Zulu", "zulu"],
num_records = 20,
#theme = "TAX_ETHNICITY_INDIGENOUS",
near = near(10, etnia, "Kenya"),
#repeat = repeat(2, etnia),
)
timevol = gd.timeline_search("timelinevolraw", f)
df = gd.article_search(f)
timevol
# Out:
#                       datetime  Article Count  All Articles
# 0    2017-01-01 00:00:00+00:00              4        427906
# 1    2017-01-02 00:00:00+00:00             10        592774
# 2    2017-01-03 00:00:00+00:00              3        757916
# 3    2017-01-04 00:00:00+00:00              4        822862
# 4    2017-01-05 00:00:00+00:00              3        830028
# ...                        ...            ...           ...
# 3147 2025-09-04 00:00:00+00:00              1        190882
# 3148 2025-09-05 00:00:00+00:00              1        192400
# 3149 2025-09-06 00:00:00+00:00              0        155749
# 3150 2025-09-07 00:00:00+00:00              1        115827
# 3151 2025-09-08 00:00:00+00:00              1        181958
#
# [3152 rows x 3 columns]

# %%
df
# Out:
#                                                   url  \
# 0   http://spanish.xinhuanet.com/20250801/35d588d1...
# 1   https://skift.com/2025/09/02/when-luxury-touri...
# 2   https://www.africanews.com/2025/08/29/elephant...
# 3   https://www.timeout.com/news/the-kenyan-safari...
# 4   https://www.yahoo.com/lifestyle/articles/29-da...
# 5   https://www.capitalfm.co.ke/lifestyle/2025/08/...
# 6   https://www.timeslive.co.za/news/africa/2025-0...
# 7   https://www.standardmedia.co.ke/national/artic...
# 8   https://www.cinemablend.com/movies/halle-berry...
# 9   https://www.luxurytravelmagazine.com/news-arti...
# 10  https://www.capitalfm.co.ke/news/2025/07/kdf-u...
# 11  https://www.capitalfm.co.ke/news/2025/07/world...
# 12  https://www.the-star.co.ke/news/2025-08-20-sta...
# 13  https://www.thestar.com.my/news/world/2025/08/...
# 14  https://www.asiaone.com/world/kenyan-activist-...
# 15  https://thenationonlineng.net/ononogbu-assumes...
# 16  https://www.tanzanianewsreports.com/luxury-tou...
# 17  https://www.standardmedia.co.ke/rift-valley/ar...
# 18  https://thewest.com.au/travel/pulling-back-the...
# 19  https://www.kenyan-post.com/2025/08/cs-miano-o...
#
#                                            url_mobile  \
# 0
# 1
# 2   /amp/2025/08/29/elephant-forced-to-drink-beer-...
# 3
# 4
# 5
# 6
# 7   https://www.standardmedia.co.ke/amp/national/a...
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15  https://thenationonlineng.net/ononogbu-assumes...
# 16
# 17  https://www.standardmedia.co.ke/amp/rift-valle...
# 18  https://thewest.com.au/travel/pulling-back-the...
# 19
#
#                                                 title          seendate  \
# 0   Grandes manadas de animales migran desde el Pa...  20250801T023000Z
# 1   When Luxury Tourism Leaves Locals Behind in Af...  20250902T184500Z
# 2   Elephant forced to drink beer at Kenyan nature...  20250829T174500Z
# 3   This Kenyan Safari Lodge Has Been Crowned The ...  20250709T190000Z
# 4   This 29 - day Private Jet Journey Will Take Yo...  20250905T153000Z
# 5   Say Yes ! 5 Magical Wedding Proposal Ideas Tha...  20250819T080000Z
# 6   Kenyan activist tries to block new Ritz - Carl...  20250813T063000Z
# 7   Government tightens rules at Maasai Mara after...  20250820T210000Z
# 8   Halle Berry Is Joining Forces With A DC Alum F...  20250805T183000Z
# 9   TCS World Travel Launches Seven Continents by ...  20250811T221500Z
# 10   KDF , US troops celebrate heritage at Manda Base  20250715T214500Z
# 11  World Book of Records to unveil Maasai Mara gl...  20250716T094500Z
# 12  CS Miano tightens rules after tourists block w...  20250820T200000Z
# 13  Kenyan activist tries to block new Ritz - Carl...  20250812T143000Z
# 14  Kenyan activist tries to block new Ritz - Carl...  20250813T033000Z
# 15  Ononogbu assumes office as chairman National P...  20250803T161500Z
# 16  Luxury Tourism Flourishes in Africa , Yet Loca...  20250822T181500Z
# 17  Marriott faces backlash over its luxurious saf...  20250729T060000Z
# 18     Pulling back the flap on the African continent  20250712T023000Z
# 19  CS MIANO orders crackdown after tourists block...  20250822T011500Z
#
#                                           socialimage  \
# 0
# 1   https://skift.com/wp-content/uploads/2022/04/4...
# 2   https://static.euronews.com/articles/stories/0...
# 3   https://media.timeout.com/images/106294382/ima...
# 4   https://s.yimg.com/ny/api/res/1.2/bqfAU0P84VRC...
# 5   https://www.capitalfm.co.ke/lifestyle/files/20...
# 6
# 7   https://cdn.standardmedia.co.ke/images/article...
# 8   https://cdn.mos.cms.futurecdn.net/bKUwQvrbdtcW...
# 9
# 10  https://www.capitalfm.co.ke/news/files/2025/07...
# 11  https://www.capitalfm.co.ke/news/files/2023/08...
# 12  https://cdn.radioafrica.digital/image/2025/08/...
# 13  https://apicms.thestar.com.my/uploads/images/2...
# 14  https://media.asiaone.com/sites/default/files/...
# 15  https://cdn.thenationonlineng.net/wp-content/u...
# 16
# 17  https://cdn.standardmedia.co.ke/images/article...
# 18  https://images.thewest.com.au/publication/C-19...
# 19
#
#                       domain language   sourcecountry
# 0      spanish.xinhuanet.com  Spanish           China
# 1                  skift.com  English   United States
# 2             africanews.com  English         Nigeria
# 3                timeout.com  English  United Kingdom
# 4                  yahoo.com  English   United States
# 5            capitalfm.co.ke  English           Kenya
# 6            timeslive.co.za  English    South Africa
# 7        standardmedia.co.ke  English           Kenya
# 8            cinemablend.com  English   United States
# 9   luxurytravelmagazine.com  English   United States
# 10           capitalfm.co.ke  English           Kenya
# 11           capitalfm.co.ke  English           Kenya
# 12            the-star.co.ke  English           Kenya
# 13            thestar.com.my  English        Malaysia
# 14               asiaone.com  English       Singapore
# 15     thenationonlineng.net  English         Nigeria
# 16   tanzanianewsreports.com  English        Tanzania
# 17       standardmedia.co.ke  English           Kenya
# 18            thewest.com.au  English       Australia
# 19           kenyan-post.com  English           Kenya

# %%
df.loc[2, "url"]
# Out:
# 'https://www.africanews.com/2025/08/29/elephant-forced-to-drink-beer-at-kenyan-nature-park/'

# %%
df
